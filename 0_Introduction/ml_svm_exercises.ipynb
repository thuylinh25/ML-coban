# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import svm

# %%
# data-point vectors
x_train = np.array([[1,0],[0,1],[1,1],[-1,-2],[-2,-3]])
# data-point label
y_train = np.array([1,1,1,0,0])

# %%
clf = svm.SVC(kernel='linear')
clf.fit(x_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
# support vectors
clf.support_vectors_
# Out:
# array([[-1., -2.],
#        [ 1.,  0.]])

# %%
# get number of support vectors for each class
clf.n_support_
# Out:
# array([1, 1], dtype=int32)

# %%
## plot the data ##
# figure number
fignum = 1
# plot the line, the points, and the nearest vectors to the plane
plt.figure(fignum, figsize=(10, 7))
plt.clf()

plt.scatter(clf.support_vectors_[0], # support vectors class 0
            clf.support_vectors_[1], # support vectors class 1
            facecolors='none', zorder=10)
plt.scatter(x_train[:, 0], x_train[:, 1], c=y_train, zorder=10, cmap=plt.cm.Paired)
plt.axis('tight')

XX, YY = np.mgrid[x_min:x_max:200j, y_min:y_max:200j]
Z = clf.decision_function(np.c_[XX.ravel(), YY.ravel()])
# Put the result into a color plot
Z = Z.reshape(XX.shape)

plt.contour(XX, YY, Z, colors=['k', 'k', 'k'], linestyles=['--', '-', '--'], levels=[-1, 0, 1])

plt.show()
